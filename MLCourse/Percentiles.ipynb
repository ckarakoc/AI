# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 1_000_000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# np.float64(-0.000907817922957405)

# %%
np.percentile(vals, 90)
# Out:
# np.float64(0.639977235994307)

# %%
np.percentile(vals, 20)
# Out:
# np.float64(-0.42127122273579004)

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?
